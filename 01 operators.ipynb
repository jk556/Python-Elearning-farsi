# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# <div align=center>
# <font face="B Nazanin" size=3>
#     به نام خدا
#     </font>
#     <br>
#     <br>
#     <font face="B Nazanin" size=5>
#         <font color=#FF7500>
#       آکادمی همراه
#         </font>
#             <br><br>
#         دورۀ آشنایی با پایتون
#         <br>
#         <br>
# <b>        متغیرها و عملگرها
#         </b>
#              </font>
#         <br>
#         <br>
#         <font face="B Nazanin" size=4>
#         <b> جمال کزازی </b>
#             <p> </p>
#     </font>
#             <p> </p>
#     </font>
#     </div>
#     </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# <div align=right>
# <font face="B Nazanin">
#     <h2>
# متغیرها    </h2>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# <div align=right>
#     <font face="B Nazanin" size=4>
#         <br>
#       در پایتون برای نگهداری داده ها از یک نام استفاده می شود که به آن متغیر گفته می شود. نحوه تعریف و استفاده از متغیرها در ادامه می‌آید:
#     </font>
#     </div>
#     </div>

# %%
x = 2
y = 5
xy = 'Hey'
yx = "Jamal's pen"
print(x)
print(type(x))
print(type(xy))
print(type(yx))
print(yx)
yx
# Out:
# 2
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Jamal's pen
# "Jamal's pen"

# %%
print (x+y, xy)
print(1,4,6,2,x,y,xy,3,4)
# Out:
# 7 Hey
# 1 4 6 2 2 5 Hey 3 4

# %% [markdown]
# ![R-2.jpg](attachment:R-2.jpg)

# %%
x = y = 1

# %%
print (x,y)
# Out:
# 1 1

# %% [markdown]
# # Operators

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# | Symbol | Task Performed |
# |----|---|
# | +  | Addition |
# | -  | Subtraction |
# | /  | division |
# | %  | mod |
# | *  | multiplication |
# | //  | floor division |
# | **  | to the power of |

# %%
1+20
# Out:
# 21

# %%
2-1
# Out:
# 1

# %%
15*11
# Out:
# 165

# %%
21/4
# Out:
# 5.25

# %% [markdown]
# 0? This is because both the numerator and denominator are integers but the result is a float value hence an integer value is returned. By changing either the numerator or the denominator to float, correct answer can be obtained.

# %%
1/2.0
# Out:
# 0.5

# %%
21%5
# Out:
# 1

# %% [markdown]
# Floor division is nothing but converting the result so obtained to the nearest integer.

# %%
100//3
# Out:
# 33

# %%
x = 5
print(x + 1)  # Addition;
print(x - 1)   # Subtraction;
print(x * 2)  # Multiplication;
print(x ** 2) # Exponentiation;
print(x / 2) #division
print(x // 2) #integer division
# Out:
# 6
# 4
# 10
# 25
# 2.5
# 2

# %% [markdown]
# ## Relational Operators

# %% [markdown]
# | Symbol | Task Performed |
# |----|---|
# | == | True, if it is equal |
# | !=  | True, if not equal to |
# | < | less than |
# | > | greater than |
# | <=  | less than or equal to |
# | >=  | greater than or equal to |

# %%
z = 3

# %%
z == 2
print(type(z==2))
# Out:
# <class 'bool'>

# %%
z > 1
# Out:
# True

# %%
t, f = True, False # t = True f= False
print(type(t)) # Prints "<type 'bool'>"
print(t and f) # Logical AND; &
print(t or f ) # Logical OR; |
print(not t)   # Logical NOT; ~
print(t != f) # Logical XOR;
# Out:
# <class 'bool'>
# False
# True
# False
# True

# %% [markdown]
# ## Bitwise Operators

# %% [markdown]
# | Symbol | Task Performed |
# |----|---|
# | &  | Logical And |
# | l  | Logical OR |
# | ^  | XOR |
# | ~  | Negate |
# | >>  | Right shift |
# | <<  | Left shift |

# %%
a = 2 #10
b = 3 #11

# %%
print (a & b)
print (bin(a&b))
# Out:
# 2
# 0b10

# %%
5 >> 1
# Out:
# 2

# %% [markdown]
# 0000 0101 -> 5
#
# Shifting the digits by 1 to the right and zero padding
#
# 0000 0010 -> 2

# %%
5 << 4
# Out:
# 80

# %% [markdown]
# 0000 0101 -> 5
#
# Shifting the digits by 1 to the left and zero padding
#
# 0000 1010 -> 10

# %% [markdown]
# # Built-in Functions

# %% [markdown]
# Python comes loaded with pre-built functions

# %% [markdown]
# ## Conversion from one system to another

# %% [markdown]
# Conversion from hexadecimal to decimal is done by adding prefix **0x** to the hexadecimal value or vice versa by using built in **hex( )**, Octal to decimal by adding prefix **0** to the octal value or vice versa by using built in function **oct( )**.

# %%
hex(170)
# Out:
# '0xaa'

# %%
0xAA
# Out:
# 170

# %%
oct(8)
# Out:
# '0o10'

# %% [markdown]
# **int( )** accepts two values when used for conversion, one is the value in a different number system and the other is its base. Note that input number in the different number system should be of string type.

# %%
print(int('010',2))
print(int('0xaa',16))
print(int('1010',2))
print(int('100')*2)
# Out:
# 2
# 170
# 10
# 200

# %% [markdown]
# **int( )** can also be used to get only the integer value of a float number or can be used to convert a number which is of type string to integer format. Similarly, the function **str( )** can be used to convert the integer back to string format

# %%
print(int(7.7))
print(int('75'))
# Out:
# 7
# 75

# %% [markdown]
# Also note that function **bin( )** is used for binary and **float( )** for decimal/float values. **chr( )** is used for converting ASCII to its alphabet equivalent, **ord( )** is used for the other way round.

# %%
d = 98
print(chr(d))
print(int(d))
# Out:
# b
# 98

# %%
ord('b')
# Out:
# 98

# %% [markdown]
# ## Simplifying Arithmetic Operations

# %% [markdown]
# **round( )** function rounds the input value to a specified number of places or to the nearest integer.

# %%
print (round(5.6231) )
print (round(4.55892, 2))
# Out:
# 6
# 4.56

# %% [markdown]
# **complex( )** is used to define a complex number and **abs( )** outputs the absolute value of the same.

# %%
c =complex('5+2j')
print (abs(c))
# Out:
# 5.385164807134504

# %% [markdown]
# **divmod(x,y)** outputs the quotient and the remainder in a tuple(you will be learning about it in the further chapters) in the format (quotient, remainder).

# %%
print(type(divmod(9,2)))
divmod(9,2)
# Out:
# <class 'tuple'>
# (4, 1)

# %% [markdown]
# **comparison**

# %%
import operator as op
l = 12
m = 8
print(op.lt(l,m))
print(op.eq(l,m))
print(op.gt(l,m))
# Out:
# False
# False
# True

# %% [markdown]
# **pow(x,y,z)** can be used to find the power $x^y$ also the mod of the resulting value with the third specified number can be found i.e. : ($x^y$ % z).

# %%
print(pow(3,3))
print(pow(3,3,5))
# Out:
# 27
# 2

# %% [markdown]
# ## Accepting User Inputs

# %%
abc = input("Type something here and it will be stored in variable abc \t")
# Out:
# Type something here and it will be stored in variable abc 	python

# %%
type(abc)
print(abc)
# Out:
# python

# %%
abc1 =  input("Only integer can be stored in variable abc \t")
# Out:
# Only integer can be stored in variable abc 	678

# %%
type(abc1)
# Out:
# str

# %% [markdown]
# Note that **type( )** returns the format or the type of a variable or a number

# %%
print(int(abc1)+1)
# Out:
# 679

# %%
z = input()
print(float(z)/2)
# Out:
# 2.5
# 1.25
